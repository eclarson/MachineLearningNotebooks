# %% [markdown]
# Installed according to https://developer.apple.com/metal/tensorflow-plugin/ and the README for this repository.
#
# You should also install graphviz as a library, but this cannot be installed completely using pip. Instead, you will need to use homebrew or install directly. For Mac, here is what is was able to follow along: https://eloquentcode.com/generate-a-diagram-for-a-keras-model-on-macos
#
# Homebrew is also nice for installing more complex packages, like openCV.

# %%
# check from https://developer.apple.com/metal/tensorflow-plugin/
import tensorflow as tf

cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(32, 32, 3),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=5, batch_size=64)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 1297s 8us/step
# 2026-08-05 11:31:16.438310: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M5 Pro
# 2026-08-05 11:31:16.438343: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2026-08-05 11:31:16.438351: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 25.92 GB
# 2026-08-05 11:31:16.438527: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-08-05 11:31:16.438538: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/5
# 2026-08-05 11:31:20.825864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 212s 242ms/step - accuracy: 0.0619 - loss: 4.9769
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 183s 234ms/step - accuracy: 0.1058 - loss: 4.3601
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 236ms/step - accuracy: 0.1412 - loss: 3.9528
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 178s 228ms/step - accuracy: 0.1793 - loss: 3.6535
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 167s 213ms/step - accuracy: 0.2043 - loss: 3.4646
